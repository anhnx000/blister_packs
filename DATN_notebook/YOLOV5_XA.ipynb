# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 416 --batch 2 --epochs 200 --data ../DATN_data/robo_sorted/v0_v10_yolo/data.yaml --weights yolov5l.pt --device 0,1
# !python ../yolov5/train.py --img 416 --batch 2 --epochs 150 --data  ../DATN_data/robo_sorted/v0_v10_yolo_drop/data_crop.yaml  --weights yolov5s.pt --device 0,3
# Out:
# /mnt/disk1/doan/.conda/envs/xanh_pack/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# Traceback (most recent call last):
#   File "../yolov5/train.py", line 41, in <module>
#     import val  # for end-of-epoch mAP
#   File "/mnt/disk1/doan/xanh/server_blister_packs/yolov5/val.py", line 37, in <module>
#     from models.common import DetectMultiBackend
#   File "/mnt/disk1/doan/xanh/server_blister_packs/yolov5/models/common.py", line 24, in <module>
#     from utils.dataloaders import exif_transpose, letterbox
#   File "/mnt/disk1/doan/xanh/server_blister_packs/yolov5/utils/dataloaders.py", line 29, in <module>
#     from utils.augmentations import Albumentations, augment_hsv, copy_paste, letterbox, mixup, random_perspective
# ...

# %%
# !python  ../yolov5/detect.py --weights ../yolov5/runs/train/exp51/weights/last.pt  --source ../DATN_data/robo_sorted/v0_v10_few_shot_raw/DATA_CHUP_yolo/images --save-txt  --device 3
# Out:
# detect: weights=['../yolov5/runs/train/exp51/weights/last.pt'], source=../DATN_data/robo_sorted/v0_v10_few_shot_raw/DATA_CHUP_yolo/images, data=../yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=3, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=../yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-202-g7d46c69 Python-3.7.11 torch-1.10.2 CUDA:3 (NVIDIA GeForce RTX 3080, 10018MiB)
#
# Fusing layers...
# Model summary: 290 layers, 20852934 parameters, 0 gradients
# image 1/432 /mnt/disk1/doan/xanh/server_blister_packs/DATN_data/robo_sorted/v0_v10_few_shot_raw/DATA_CHUP_yolo/images/22_forxiga_10__(12).jpg: 384x640 1 pill, Done. (0.040s)
# ...
